# %% [markdown]
# ## **Criação da base de dados de treinamento e teste.**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Importando base de dados completa

# %%
df_completo = pd.read_csv("/content/drive/MyDrive/MICRODADOS_ENEM_2021.csv", header = 0, delimiter = ';', encoding='latin-1')

# %%
df_completo.sample(4)
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 2470767  210053468425    2021                4       F                1
# 2527046  210053986629    2021                3       M                1
# 2660187  210053623550    2021                1       F                1
# 776525   210052193687    2021                2       F                1
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 2470767            1                 1                1                2
# 2527046            1                 1                2                0
# 2660187            1                 1                3                0
# 776525             3                 1                2                0
#
#          TP_ESCOLA  ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  \
# 2470767          1  ...     B     A     B    D     B    B     E     A     C
# 2527046          2  ...     A     A     A    B     A    A     C     A     B
# 2660187          1  ...     B     A     A    E     B    A     E     A     C
# 776525           2  ...     A     A     A    B     A    A     D     A     A
#
#          Q025
# 2470767     B
# 2527046     B
# 2660187     B
# 776525      B
#
# [4 rows x 76 columns]

# %% [markdown]
# # Criação de dataframe com os campos importantes para o estudo. Isto reduzirá o tamanho da base de dados.

# %%
df_enem_2021 = df_completo[["NU_INSCRICAO", "TP_FAIXA_ETARIA","TP_SEXO","Q006", "Q025", 
                        "NU_NOTA_REDACAO", "NU_INSCRICAO", "TP_DEPENDENCIA_ADM_ESC",
                         "CO_MUNICIPIO_PROVA"]].query("NU_NOTA_REDACAO > 0")

# %%
print(len(df_enem_2021))
# Out:
# 2293797

# %%
df_enem_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2293797 entries, 0 to 3389830
# Data columns (total 9 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   NU_INSCRICAO            int64
#  1   TP_FAIXA_ETARIA         int64
#  2   TP_SEXO                 object
#  3   Q006                    object
#  4   Q025                    object
#  5   NU_NOTA_REDACAO         float64
#  6   NU_INSCRICAO            int64
#  7   TP_DEPENDENCIA_ADM_ESC  float64
#  8   CO_MUNICIPIO_PROVA      int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 175.0+ MB

# %%
df_enem_2021.isnull().mean()
# Out:
# NU_INSCRICAO              0.000000e+00
# TP_FAIXA_ETARIA           0.000000e+00
# TP_SEXO                   0.000000e+00
# Q006                      4.359584e-07
# Q025                      4.359584e-07
# NU_NOTA_REDACAO           0.000000e+00
# NU_INSCRICAO              0.000000e+00
# TP_DEPENDENCIA_ADM_ESC    7.352547e-01
# CO_MUNICIPIO_PROVA        0.000000e+00
# dtype: float64

# %% [markdown]
# # O campo TP_DEPENDENCIA_ADM_ESC será retirado do estudo por possuir muitos dados faltantes, cerca de 74%.

# %%
df_enem_2021.drop(["TP_DEPENDENCIA_ADM_ESC"], axis = 1, inplace = True)

# %%
df_enem_2021.isna().sum()
# Out:
# NU_INSCRICAO          0
# TP_FAIXA_ETARIA       0
# TP_SEXO               0
# Q006                  1
# Q025                  1
# NU_NOTA_REDACAO       0
# NU_INSCRICAO          0
# CO_MUNICIPIO_PROVA    0
# dtype: int64

# %%
df_enem_2021.fillna(axis=0, method='ffill')
# Out:
#          NU_INSCRICAO  TP_FAIXA_ETARIA TP_SEXO Q006 Q025  NU_NOTA_REDACAO  \
# 0        210053865474                5       F    D    B            760.0
# 1        210052384164               12       M    B    A            560.0
# 3        210052128335                3       M    B    B            780.0
# 4        210051353021                2       F    C    B            780.0
# 6        210052615524                9       F    C    B            480.0
# ...               ...              ...     ...  ...  ...              ...
# 3389793  210054306230               15       F    D    B            240.0
# 3389807  210051254419               14       M    E    B            320.0
# 3389814  210051121001               10       M    B    B            640.0
# 3389815  210051173067                5       F    A    B            540.0
# 3389830  210051139675                7       F    E    B            660.0
#
#          NU_INSCRICAO  CO_MUNICIPIO_PROVA
# 0        210053865474             3144805
# 1        210052384164             2704302
# 3        210052128335             2304202
# 4        210051353021             2300150
# 6        210052615524             4321600
# ...               ...                 ...
# 3389793  210054306230             3530706
# 3389807  210051254419             3167202
# 3389814  210051121001             3303203
# 3389815  210051173067             1304237
# 3389830  210051139675             3152501
#
# [2293797 rows x 8 columns]

# %%
df_enem_2021.describe()
# Out:
#        NU_INSCRICAO  TP_FAIXA_ETARIA  NU_NOTA_REDACAO  NU_INSCRICAO  \
# count  2.293797e+06     2.293797e+06     2.293797e+06  2.293797e+06
# mean   2.100527e+11     4.532460e+00     6.361228e+02  2.100527e+11
# std    9.968794e+05     3.545920e+00     1.527170e+02  9.968794e+05
# min    2.100510e+11     1.000000e+00     4.000000e+01  2.100510e+11
# 25%    2.100519e+11     2.000000e+00     5.400000e+02  2.100519e+11
# 50%    2.100527e+11     3.000000e+00     6.200000e+02  2.100527e+11
# 75%    2.100536e+11     6.000000e+00     7.400000e+02  2.100536e+11
# max    2.100545e+11     2.000000e+01     1.000000e+03  2.100545e+11
#
#        CO_MUNICIPIO_PROVA
# count        2.293797e+06
# mean         3.121965e+06
# std          9.896328e+05
# min          1.100015e+06
# 25%          2.409407e+06
# 50%          3.132404e+06
# 75%          3.550308e+06
# max          5.300108e+06

# %% [markdown]
# # Criação da base de treinamento e teste

# %%
msk = np.random.rand(len(df_enem_2021)) < 0.8 # cria uma mascara com as posicoes
train = df_enem_2021[msk]
test = df_enem_2021[~msk]

# %%
train.sample(4)
# Out:
#          NU_INSCRICAO  TP_FAIXA_ETARIA TP_SEXO Q006 Q025  NU_NOTA_REDACAO  \
# 1100392  210052920633                2       M    H    B            900.0
# 1252666  210052453219                2       F    B    A            460.0
# 468845   210051905443                2       F    D    B            760.0
# 2974998  210052539772                1       M    F    B            560.0
#
#          NU_INSCRICAO  CO_MUNICIPIO_PROVA
# 1100392  210052920633             3106200
# 1252666  210052453219             2109106
# 468845   210051905443             3304557
# 2974998  210052539772             2307809

# %%
test.sample(4)
# Out:
#          NU_INSCRICAO  TP_FAIXA_ETARIA TP_SEXO Q006 Q025  NU_NOTA_REDACAO  \
# 773666   210052329217                5       F    D    B            920.0
# 1700482  210051196377                3       F    B    B            580.0
# 3365306  210052960575               13       F    D    B            560.0
# 929081   210053982024                2       M    B    B            560.0
#
#          NU_INSCRICAO  CO_MUNICIPIO_PROVA
# 773666   210052329217             2929305
# 1700482  210051196377             2609501
# 3365306  210052960575             3550308
# 929081   210053982024             2112704

# %%
print(len(train))
print(len(test))
# Out:
# 1834835
# 458962

# %%
train.to_csv("/content/drive/MyDrive/ENEM_2021_TRAIN.csv")
test.to_csv("/content/drive/MyDrive/ENEM_2021_TEST.csv")

# %% [markdown]
# # Separando variáveis de Entrada (x) e Saída (y)

# %%
y_train = train[["NU_NOTA_REDACAO"]]
y_test = test[["NU_NOTA_REDACAO"]]
x_train = train
x_train.drop(["NU_NOTA_REDACAO"], axis=1, inplace=True)
x_test = test
x_test.drop(["NU_NOTA_REDACAO"], axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
x_train.sample(2)
# Out:
#          NU_INSCRICAO  TP_FAIXA_ETARIA TP_SEXO Q006 Q025  NU_INSCRICAO  \
# 491021   210052402414                3       M    C    B  210052402414
# 2049685  210051697127                3       M    P    B  210051697127
#
#          CO_MUNICIPIO_PROVA
# 491021              2304400
# 2049685             3549805
